# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\hp\\Downloads\\python project data sets\\car info\\Automobile.csv")
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
df.head()#first 5 values
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.tail()#last 5 values
# Out:
#                 name   mpg  cylinders  displacement  horsepower  weight  \
# 393  ford mustang gl  27.0          4         140.0        86.0    2790
# 394        vw pickup  44.0          4          97.0        52.0    2130
# 395    dodge rampage  32.0          4         135.0        84.0    2295
# 396      ford ranger  28.0          4         120.0        79.0    2625
# 397       chevy s-10  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin
# 393          15.6          82     usa
# 394          24.6          82  europe
# 395          11.6          82     usa
# 396          18.6          82     usa
# 397          19.4          82     usa

# %%
df.info()#info about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.shape #row and column
# Out:
# (398, 9)

# %%
#to check null values
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df['mpg'] = df['mpg'].astype('int')

# %%
df['displacement']=df['displacement'].astype('int')

# %%
df['acceleration']=df['acceleration'].astype('int')

# %%
pd.isnull(df).sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          392 non-null    object
#  1   mpg           392 non-null    int32
#  2   cylinders     392 non-null    int64
#  3   displacement  392 non-null    int32
#  4   horsepower    392 non-null    float64
#  5   weight        392 non-null    int64
#  6   acceleration  392 non-null    int32
#  7   model_year    392 non-null    int64
#  8   origin        392 non-null    object
# dtypes: float64(1), int32(3), int64(3), object(2)
# memory usage: 26.0+ KB

# %%
df['horsepower']=df['horsepower'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          392 non-null    object
#  1   mpg           392 non-null    int32
#  2   cylinders     392 non-null    int64
#  3   displacement  392 non-null    int32
#  4   horsepower    392 non-null    int32
#  5   weight        392 non-null    int64
#  6   acceleration  392 non-null    int32
#  7   model_year    392 non-null    int64
#  8   origin        392 non-null    object
# dtypes: int32(4), int64(3), object(2)
# memory usage: 24.5+ KB

# %%
#null values removed

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.283163    5.471939    194.410714  104.469388  2977.584184
# std      7.745896    1.705783    104.645191   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.500000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.000000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.186224   75.979592
# std        2.743700    3.683737
# min        8.000000   70.000000
# 25%       13.000000   73.000000
# 50%       15.000000   76.000000
# 75%       17.000000   79.000000
# max       24.000000   82.000000

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.780143     -0.806765   -0.779415 -0.835080
# cylinders    -0.780143   1.000000      0.950823    0.842983  0.897527
# displacement -0.806765   0.950823      1.000000    0.897255  0.932996
# horsepower   -0.779415   0.842983      0.897255    1.000000  0.864538
# weight       -0.835080   0.897527      0.932996    0.864538  1.000000
# acceleration  0.403785  -0.486055     -0.522269   -0.673877 -0.402713
# model_year    0.569008  -0.345647     -0.369838   -0.416361 -0.309120
#
#               acceleration  model_year
# mpg               0.403785    0.569008
# cylinders        -0.486055   -0.345647
# displacement     -0.522269   -0.369838
# horsepower       -0.673877   -0.416361
# weight           -0.402713   -0.309120
# acceleration      1.000000    0.261773
# model_year        0.261773    1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          392 non-null    object
#  1   mpg           392 non-null    int32
#  2   cylinders     392 non-null    int64
#  3   displacement  392 non-null    int32
#  4   horsepower    392 non-null    int32
#  5   weight        392 non-null    int64
#  6   acceleration  392 non-null    int32
#  7   model_year    392 non-null    int64
#  8   origin        392 non-null    object
# dtypes: int32(4), int64(3), object(2)
# memory usage: 32.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          392 non-null    object
#  1   mpg           392 non-null    int32
#  2   cylinders     392 non-null    int64
#  3   displacement  392 non-null    int32
#  4   horsepower    392 non-null    int32
#  5   weight        392 non-null    int64
#  6   acceleration  392 non-null    int32
#  7   model_year    392 non-null    int64
#  8   origin        392 non-null    object
# dtypes: int32(4), int64(3), object(2)
# memory usage: 32.6+ KB

# %%
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
e=sns.histplot(df.corr())
e
for bars in e.containers:
    e.bar_label(bars)

# %%
#this plot tells no of times these parameters come in range from -1 to +1
#there is inverse relation between -ve corr and +ve corr columns
#if both columns are coming in +ve corr or -ve corr it means these are directly related to each other.

# %%
#we will find plot between 2 columns using this hist plot

# %% [raw]
# from this we have to check relationship between each and every column then only we can perform analysis

# %% [markdown]
# # cylinders and model year

# %%
a=df.groupby(['model_year'],as_index=False)['cylinders'].sum()
b=sns.barplot(x='model_year',y='cylinders',data=a)
for bars in b.containers:
    b.bar_label(bars)

# %%
#from this we can tell that in the year 73 most of the cylinders are been sold and in the year 80 less cylinders are been sold.

# %% [markdown]
# # weight vs model year

# %%
a=df.groupby(['model_year'],as_index=False)['weight'].sum()
b=sns.barplot(x='model_year',y='weight',data=a)
for bars in b.containers:
    b.bar_label(bars)

# %%
#from this we can tell that since many cylinders are been sold in the year 73 so the weight of the cylinders are also high in the 
#year , similarly in the year 80 less productio  of cylinders took place so the weight of cylinders are less in year 80.

# %% [markdown]
# # model_year vs mpg

# %%
a=df.groupby(['model_year'],as_index=False)['mpg'].sum()
b=sns.barplot(x='model_year',y='mpg',data=a)
for bars in b.containers:
    b.bar_label(bars)

# %%
#from this we can tell that since in the year 80 less production of cylinders took place so due to this the mpg was more in the 
#year of 80 from this we can conclude that there is an inverse relationship between mpg and weight,cylinders

# %% [markdown]
# # model_year vs acceleration

# %%
a=df.groupby(['model_year'],as_index=False)['acceleration'].sum()
b=sns.barplot(x='model_year',y='acceleration',data=a)
for bars in b.containers:
    b.bar_label(bars)

# %%
#from this we can tell that since weight and cyclinders are increasing so dut to this the acceleration also increases so 
#from this graph we can tell that in the year 78 acceleration was max because of the rise of cylinders and weight .
#there is a inverse relationship between acceleration , cylinders and weight and we have direct relationship with mpg

# %% [markdown]
# # model year vs displacement

# %%
a=df.groupby(['model_year'],as_index=False)['displacement'].sum()
b=sns.barplot(x='model_year',y='displacement',data=a)
for bars in b.containers:
    b.bar_label(bars)

# %%
#from this we can tell that since weight and cyclinders are increasing so dut to this the acceleration also increases so
#due to this reason displacement also increases in the year 73 as in the year 78 acceleration was max because of the fall of cylinders and weight .
#So there is a inverse relationship between displacement ,weight ,cylinders and direct relationship with mpg and acceleration

# %% [markdown]
# # model_year vs horsepower

# %%
a=df.groupby(['model_year'],as_index=False)['horsepower'].sum()
b=sns.barplot(x='model_year',y='horsepower',data=a)
for bars in b.containers:
    b.bar_label(bars)

# %%
#directly related with displacement , cylinders, weight and inversely related with acceleration and mpg

# %% [raw]
# 1) relations - displacement , cylinders , weight ,horsepower
# 2) relations - mpg , acceleration and model_year

# %%
#perform data analysis

# %% [markdown]
# # displacement vs cylinders

# %%
a=df.groupby(['cylinders'],as_index=False)['displacement'].sum()
b=sns.barplot(x='cylinders',y='displacement',data=a)
for bars in b.containers:
    b.bar_label(bars)

# %%
#from this  we can tell that 8 cylinders have purchased more by the customers ,due to this reason the displacement of 8 cylinders is more
#since 3 cylinders have purchased less by the customers due to this reason the displacement of 3 cylinders is very less
#directly related to each other (displacement and cylinders)

# %%
b=sns.violinplot(x='cylinders',y='displacement',data=df)
for bars in b.containers:
    b.bar_label(bars)

# %% [raw]
# from this we can conclude that cylinder 3 and cylinder 8 have some abnormalities , this means these 2 values are out of range.

# %% [markdown]
# # cylinders vs horse power

# %%
a=df.groupby(['cylinders'],as_index=False)['horsepower'].sum()

b=sns.barplot(x='cylinders',y='horsepower',data=df)
for bars in b.containers:
    b.bar_label(bars)

# %%
#from this  we can tell that 8 cylinders have purchased more by the customers ,due to this reason the horsepower
#of 8 cylinders is more since 3 cylinders have purchased less by the customers 
#due to this reason the horsepower of 3 cylinders is very less

# %%
#to check abnormalities

# %%
b=sns.boxplot(x='cylinders',y='horsepower',data=df)
for bars in b.containers:
    b.bar_label(bars)

# %% [raw]
# from this we can tell that cylinders with 6 and 8 have abnormalities , this means that there are 2 values which are out of range

# %% [markdown]
# # mpg vs modelyear

# %%
b=sns.barplot(x='model_year',y='mpg',data=df)
for bars in b.containers:
    b.bar_label(bars)

# %% [raw]
# from this we can tell that in the year 80 mpg is more and from this analysis we tell that as the years are passing
# mpg is increasing but not linearly

# %%
#to find ab normality in the graph

# %%
b=sns.boxplot(x='model_year',y='mpg',data=df)
for bars in b.containers:
    b.bar_label(bars)

# %% [raw]
# from the analysis we observed that in the year 78 some abnormalities are there , this means that some values are out of the index
# in 78 years , mpg has 1 record out of the index

# %% [markdown]
# # model year and acceleration

# %%
b=sns.barplot(x='model_year',y='acceleration',data=df)
for bars in b.containers:
    b.bar_label(bars)

# %% [raw]
# from this we can tell that in the year 80 acceleration is more and from this analysis we tell that as the years are passing
# acceleration is increasing but not linearly

# %%
#to check abnormalities

# %%
b=sns.boxplot(x='model_year',y='acceleration',data=df)
for bars in b.containers:
    b.bar_label(bars)

# %% [raw]
# from this box plot we came to know that in the year 71 ,72 ,74 ,78 ,79 ,82 there are some acceleration values which are out of range ,total 6 records are out of the range
